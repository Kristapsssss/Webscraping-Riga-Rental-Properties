# %% [markdown]
# # Import Statements

# %%
pip install opencage geopy requests
# Out:
# Collecting opencage
#   Downloading opencage-2.4.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (2.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Collecting backoff>=2.2.1 (from opencage)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy) (2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Installing collected packages: backoff, opencage
# Successfully installed backoff-2.2.1 opencage-2.4.0

# %%
import pandas as pd
import re
from opencage.geocoder import OpenCageGeocode
import time
import random
import numpy as np
import plotly.express as px

# %% [markdown]
# # Load the Data

# %%
df_data = pd.read_csv('riga_listings.csv')

# %% [markdown]
# # Preliminary Data Exploration
#
# * What is the shape of `df_data`?
# * How many rows and columns does it have?
# * What are the column names?
# * Are there any NaN values or duplicates?

# %%
df_data.shape
# Out:
# (1327, 7)

# %%
df_data.columns
# Out:
# Index(['Title', 'Location', 'Rooms', 'Size', 'Floor', 'Series', 'Price'], dtype='object')

# %%
df_data.isna().any()
# Out:
# Title       False
# Location    False
# Rooms       False
# Size        False
# Floor       False
# Series      False
# Price       False
# dtype: bool

# %%
df_data.duplicated().value_counts()
# Out:
# False    1322
# True        5
# Name: count, dtype: int64

# %%
df_data[df_data.duplicated() == True]
# Out:
#                                                   Title  \
# 234   Izīrē ilgtermiņā 2 istabu dzīvokli pilsētas ce...
# 494   Сдам квартиру, желательно на длительный срок. ...
# 804   Аренда на короткий срок. Посуточная аренда нов...
# 1070  Сдаем 1-комнатную квартиру, со всеми удобствам...
# 1172  Atsevišķa ieeja - arī ideāli saistītam ar medi...
#
#                       Location Rooms  Size Floor    Series        Price
# 234          centrsMaiznīcas 8     2    50   1/2   P. kara  380  €/mēn.
# 494     MežciemsEizenšteina 19     2    49   4/5  LT proj.  400  €/mēn.
# 804           PļavniekiDzeņu 1     2    50   3/9      602.  45  €/dienā
# 1070    ImantaJūrmalas g. 115b     1    50   2/2  Priv. m.  275  €/mēn.
# 1172  ĀgenskalnsLiepājas 40k12     3    70   1/4   Specpr.  195  €/mēn.

# %% [markdown]
# # Data Cleaning
# * Remove Duplicate Listings
# * Clean Location Data
# * Clean Price Data
# * Create latitude and longitude columns for visualization purposes

# %% [markdown]
# ## Remove Duplicate Listings

# %%
df_data[df_data['Location'] == 'centrsMaiznīcas 8']
# Out:
#                                                  Title           Location  \
# 224  Izīrē ilgtermiņā 2 istabu dzīvokli pilsētas ce...  centrsMaiznīcas 8
# 234  Izīrē ilgtermiņā 2 istabu dzīvokli pilsētas ce...  centrsMaiznīcas 8
#
#     Rooms  Size Floor   Series        Price
# 224     2    50   1/2  P. kara  380  €/mēn.
# 234     2    50   1/2  P. kara  380  €/mēn.

# %%
df_data = df_data.drop_duplicates()

# %%
df_data.duplicated().value_counts()
# Out:
# False    1322
# Name: count, dtype: int64

# %% [markdown]
# ## Clean Location Data
# * Create a function to split the location column into address and location columns
# * Change address column to contain full address including city and country

# %%
df_data.sample(30)
df_data[df_data['Location'] == 'PurvciemsVaidavas 6 k-2/3']
# Out:
#                                                  Title  \
# 722  Сдаётся уютная 2х комнатная квартира в Пурвцие...
#
#                       Location Rooms  Size Floor Series        Price
# 722  PurvciemsVaidavas 6 k-2/3     2    53   1/5  Jaun.  250  €/mēn.

# %% [markdown]
# Here we have a function to take in row location data and split the string into a district and address column according to the row index. Finding the correct regex through a lot of trial and error since the data has a lot variance in location string structure.
#
# Examples:
#
# * centrs	Bruņinieku 115B
# * centrsPulkv.Brieža 10
# * ImantaKurzemes pr. 120
# * Šampēteris-PleskodāleZalves 43
#
# So I needed a regex to find the last capitilized letter which is preceeded by a lower-case letter not a number, special character [".", "-" etc..]
#
# Once case where the regex doesnt work is:
#
# * centrs13. janvāra 21
#
# Since the name of the street starts with a number which is an outlier in the dataset.

# %%
def split_at_last_capitalized_letter(s):
    # Regex to find the last capitalized letter (preceded by a non-capitalized letter) followed by at least 1 non-capitalized letter and any combination of letters, numbers, and characters
    match = re.search(r'(.+[a-zāčēģīķļņšūž])([A-ZĀČĒĢĪĶĻŅŠŪŽ][\w\W]*)$', s)
    if match:
        district = match.group(1)
        address = match.group(2)
        return district, address
    else:
        # If no match is found, return the original string and an empty string
        return s, 'N/A'

for index, row in df_data.iterrows():
  location_series = split_at_last_capitalized_letter(row['Location'])
  df_data.loc[index, 'District'], df_data.loc[index, 'Address'] = location_series

# %%
df_data.loc[df_data['District'] == 'centrs13. janvāra 21', 'Address'] = '13. janvāra 21'
df_data.loc[df_data['Address'] == '13. janvāra 21', 'District'] = 'centrs'

# %%
df_data['District'].value_counts()
# Out:
# District
# centrs                    616
# Āgenskalns                 79
# Purvciems                  67
# Teika                      53
# Imanta                     47
# Pļavnieki                  40
# Ķengarags                  38
# Sarkandaugava              36
# Vecrīga                    35
# Maskavas priekšpilsēta     34
# Ziepniekkalns              33
# Šampēteris-Pleskodāle      31
# Krasta r-ns                23
# Iļģuciems                  21
# Jugla                      19
# Mežciems                   17
# Zolitūde                   15
# Mežaparks                  14
# Vecmīlgrāvis               14
# Dārzciems                  13
# Čiekurkalns                12
# Grīziņkalns                10
# Klīversala                  8
# Torņakalns                  8
# Dzegužkalns                 7
# Mangaļi                     7
# Ķīpsala                     5
# Bolderāja                   4
# Daugavgrīva                 4
# Katlakalns                  2
# Šķirotava                   2
# Mangaļsala                  2
# Stacija-Tirgus              1
# Bieriņi                     1
# Zasulauks                   1
# Dreiliņi                    1
# Kundziņsala                 1
# Brekši                      1
# Name: count, dtype: int64

# %%
df_data.drop(columns='Location', inplace=True)

# %%
df_data['FullAddress'] = df_data['Address'] + ', Riga, Latvia'
df_data.drop(columns='Address', inplace=True)

# %% [markdown]
# ## Clean Price Data
# * Some listings are made as a daily price, we will convert it to monthly.
# * Convert price column to integer dtype.

# %%
def convert_price(price_str):

  price_str = price_str.replace(',', '')

  if 'dienā' in price_str:
    price_per_day = re.findall(r'\d+', price_str)[0]
    monthly_price = int(price_per_day) * 30
  else:
    monthly_price = re.findall(r'\d+', price_str)[0]
  return int(monthly_price)

df_data['Price'] = df_data['Price'].apply(convert_price)

# %%
df_data['Price'].describe()
# Out:
# count     1322.000000
# mean       683.401664
# std        742.377976
# min         30.000000
# 25%        300.000000
# 50%        460.000000
# 75%        850.000000
# max      12900.000000
# Name: Price, dtype: float64

# %% [markdown]
# We can see prices listed for 30/month and 12900/month, these have been errors made by the person listing the post. We will have to find listing erros and get rid of these anomalies.
# * Daily price listed as monthly
# * Monthly price listed as daily

# %%
df_data.loc[df_data['Price'] == 30, 'Price'] = 900
df_data.loc[df_data['Price'] == 12900, 'Price'] = 12900 / 30
df_data.loc[df_data['Price'] == 10500, 'Price'] = 10500 / 30

# %% [markdown]
# ## Create latitude and longitude columns for visualization purposes

# %%
df_data['Latitude'] = np.nan
df_data['Longitude'] = np.nan

df_data[df_data['Latitude'].isna()]
# Out:
#                                                   Title Rooms  Size Floor  \
# 0     Bez starpniekiem un bez komisijas maksas, tieš...     3    70   7/9
# 1     Izīrē nelielu dzīvokli jaunbūvē Rīgas centrā -...     1    26   2/5
# 2     Izīrē nelielu, bet pilnībā aprīkotu dzīvokli p...     1    20   2/5
# 3     Izīrē mājīgu 75 kvadrātmetru divstāvīgu dzīvok...     3    75   2/2
# 4     Tiek izīrēts ļoti saulains un silts trīs istab...     3    63   5/9
# ...                                                 ...   ...   ...   ...
# 1322  Istabas 16M²(Caurstaigājama), 11M², 2, 5m²apģē...     2    40   1/5
# 1323  Uz īri tiek piedāvāts 2-istabu dzīvoklis unikā...     2    69   3/6
# 1324  Uz īri tiek piedāvāts 3-istabu dzīvoklis unikā...     3   123   4/6
# 1325  Izīrē 1 istabu 4-istabu dzīvoklī. Slēdzama kāp...     1    15   5/5
# 1326  New apartment in the center of Riga. Beautiful...     2    61   3/5
#
#        Series  Price  District                   FullAddress  Latitude  \
# 0       Jaun.    830    centrs       Klijānu 6, Riga, Latvia       NaN
# 1       Jaun.    580    centrs        Stabu 2a, Riga, Latvia       NaN
# 2      Renov.    400    centrs     Lāčplēša 53, Riga, Latvia       NaN
# 3     P. kara    490    centrs    Hospitāļu 5a, Riga, Latvia       NaN
# 4        602.    450  Mežciems  Eizenšteina 31, Riga, Latvia       NaN
# ...       ...    ...       ...                           ...       ...
# 1322   Hrušč.    350   Mangaļi     Ostas pr. 6, Riga, Latvia       NaN
# 1323    Jaun.   1400   Vecrīga      Vāgnera 11, Riga, Latvia       NaN
# 1324    Jaun.   3500   Vecrīga      Vāgnera 11, Riga, Latvia       NaN
# 1325  P. kara    175    centrs       Briāna 20, Riga, Latvia       NaN
# 1326   Renov.    790    centrs      Tirgoņu 11, Riga, Latvia       NaN
#
#       Longitude
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1322        NaN
# 1323        NaN
# 1324        NaN
# 1325        NaN
# 1326        NaN
#
# [1322 rows x 10 columns]

# %%
api_key = "my_api_key_would_be_here :)"
geolocator = OpenCageGeocode(api_key)

def get_lat_lon(address):
  try:
    location = geolocator.geocode(address)
    if location:
      print(location[0]['geometry']['lat'], location[0]['geometry']['lng'])
      return location[0]['geometry']['lat'], location[0]['geometry']['lng']
    else:
      return None, None
  except Exception as e:
    print(f"Error: {e}")
    return None, None

def retry_missing_coords(df):
    current_listing = 0
    for index, row in df.iterrows():
        retry_count = 0
        max_retries = 5
        current_listing += 1
        while (pd.isna(row['Latitude']) or pd.isna(row['Longitude'])) and retry_count < max_retries:
            lat, lon = get_lat_lon(row['FullAddress'])
            print(f"Retrying: {row['FullAddress']}, Attempt: {retry_count + 1}")
            if lat is not None and lon is not None:
                print(f"Successfull. Now on: {current_listing}")
                df.at[index, 'Latitude'] = lat
                df.at[index, 'Longitude'] = lon
                break
            else:
                retry_count += 1
                # Exponential backoff with jitter
                wait_time = (2 ** retry_count) + random.uniform(0, 1)
                print(f"Waiting for {wait_time} seconds before next retry.")
                time.sleep(wait_time)
        if retry_count == max_retries:
            print(f"Failed to get coordinates for {row['FullAddress']} after {max_retries} attempts.")

retry_missing_coords(df_data)

# %%
df_data[df_data['Longitude'].isna()]
df_data['District'][(df_data['Latitude'] == 56.946000) & (df_data['Longitude'] == 24.105890)].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# Looks like geocoding had trouble with 94 addresses, which we will try to assign a district coordinate instead.

# %%
district_geolocations = {
    'centrs': (56.9496, 24.1052),
    'Imanta': (56.9519, 24.0148),
    'Čiekurkalns': (56.9771, 24.1811),
    'Āgenskalns': (56.9386, 24.0752),
    'Mežaparks': (56.9818, 24.1395),
    'Purvciems': (56.9498, 24.1576),
    'Ķīpsala': (56.9496, 24.0898),
    'Sarkandaugava': (56.9835, 24.1353),
    'Mangaļi': (57.0016, 24.1445),
    'Jugla': (56.9764, 24.2099),
    'Pļavnieki': (56.9348, 24.1935),
    'Torņakalns': (56.9364, 24.0853),
    'Dzegužkalns': (56.9451, 24.0841),
    'Kundziņsala': (56.9985, 24.1061),
    'Iļģuciems': (56.9423, 24.0517),
    'Vecrīga': (56.9489, 24.1064),
    'Teika': (56.9753, 24.1917),
    'Klīversala': (56.9402, 24.0931),
    'Vecmīlgrāvis': (57.0314, 24.1365),
    'Zasulauks': (56.9401, 24.0728),
    'Šampēteris-Pleskodāle': (56.9293, 24.0533),
}

# Function to update latitude and longitude based on district
def update_geolocation(row):
    if (row['Latitude'] == 56.946) and (row['Longitude'] == 24.10589):
        district = row['District']
        if district in district_geolocations:
            return district_geolocations[district]
    return row['Latitude'], row['Longitude']

# Apply the function to update the DataFrame
df_data[['Latitude', 'Longitude']] = df_data.apply(update_geolocation, axis=1, result_type='expand')

df_data
# Out:
#                                                   Title Rooms  Size Floor  \
# 0     Bez starpniekiem un bez komisijas maksas, tieš...     3    70   7/9
# 1     Izīrē nelielu dzīvokli jaunbūvē Rīgas centrā -...     1    26   2/5
# 2     Izīrē nelielu, bet pilnībā aprīkotu dzīvokli p...     1    20   2/5
# 3     Izīrē mājīgu 75 kvadrātmetru divstāvīgu dzīvok...     3    75   2/2
# 4     Tiek izīrēts ļoti saulains un silts trīs istab...     3    63   5/9
# ...                                                 ...   ...   ...   ...
# 1322  Istabas 16M²(Caurstaigājama), 11M², 2, 5m²apģē...     2    40   1/5
# 1323  Uz īri tiek piedāvāts 2-istabu dzīvoklis unikā...     2    69   3/6
# 1324  Uz īri tiek piedāvāts 3-istabu dzīvoklis unikā...     3   123   4/6
# 1325  Izīrē 1 istabu 4-istabu dzīvoklī. Slēdzama kāp...     1    15   5/5
# 1326  New apartment in the center of Riga. Beautiful...     2    61   3/5
#
#        Series  Price  District                   FullAddress   Latitude  \
# 0       Jaun.    830    centrs       Klijānu 6, Riga, Latvia  56.972656
# 1       Jaun.    580    centrs        Stabu 2a, Riga, Latvia  56.959529
# 2      Renov.    400    centrs     Lāčplēša 53, Riga, Latvia  56.952321
# 3     P. kara    490    centrs    Hospitāļu 5a, Riga, Latvia  56.969687
# 4        602.    450  Mežciems  Eizenšteina 31, Riga, Latvia  56.968072
# ...       ...    ...       ...                           ...        ...
# 1322   Hrušč.    350   Mangaļi     Ostas pr. 6, Riga, Latvia  57.001600
# 1323    Jaun.   1400   Vecrīga      Vāgnera 11, Riga, Latvia  56.948488
# 1324    Jaun.   3500   Vecrīga      Vāgnera 11, Riga, Latvia  56.948488
# 1325  P. kara    175    centrs       Briāna 20, Riga, Latvia  56.964585
# 1326   Renov.    790    centrs      Tirgoņu 11, Riga, Latvia  56.948537
#
#       Longitude
# 0     24.149312
# 1     24.121525
# 2     24.130213
# 3     24.135034
# 4     24.232766
# ...         ...
# 1322  24.144500
# 1323  24.111243
# 1324  24.111243
# 1325  24.131486
# 1326  24.106336
#
# [1322 rows x 10 columns]

# %%
# Create a scatter plot on a Mapbox map
fig = px.scatter_mapbox(
    df_data,
    lat="Latitude",
    lon="Longitude",
    hover_name="Title",
    hover_data={"District": True, "Price": True, "Rooms": True, "Size": True, "FullAddress": True},
    color="Price",
    color_continuous_scale='Bluered',
    size="Price",
    zoom=9,
    height=600,
)

# Update the layout to use an appropriate Mapbox style
fig.update_layout(
    mapbox_style="open-street-map",
    title="Real Estate Listings in Riga"
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5bbffcc5-948c-4886-905a-4ea71510ae21" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bbffcc5-948c-4886-905a-4ea71510ae21")) {                    Plotly.newPlot(                        "5bbffcc5-948c-4886-905a-4ea71510ae21",                        [{"customdata":[["centrs",830,"3",70,"Klij\u0101nu 6, Riga, Latvia"],["centrs",580,"1",26,"Stabu 2a, Riga, Latvia"],["centrs",400,"1",20,"L\u0101\u010dpl\u0113\u0161a 53, Riga, Latvia"],["centrs",490,"3",75,"Hospit\u0101\u013cu 5a, Riga, Latvia"],["Me\u017eciems",450,"3",63,"Eizen\u0161teina 31, Riga, Latvia"],["\u0100genskalns",300,"1",28,"B\u0101ri\u0146u 8, Riga, Latvia"],["P\u013cavnieki",300,"1",48,"Saharova 15, Riga, Latvia"],["Krasta r-ns",430,"3",60,"Zilupes 31, Riga, Latvia"],["\u0136engarags",250,"1",33,"Maskavas 425, Riga, Latvia"],["centrs",900,"2",75,"R\u016bpniec\u012bbas 21, Riga, Latvia"],["Imanta",750,"2",62,"Dumbr\u0101ja 29, Riga, Latvia"],["centrs",750,"2",34,"Rai\u0146a bulv. 27, Riga, Latvia"],["Imanta",600,"3",62,"Kurzemes pr. 128, Riga, Latvia"],["Teika",210,"1",29,"Ropa\u017eu 76, Riga, Latvia"],["I\u013c\u0123uciems",130,"1",18,"St\u016bres 2, Riga, Latvia"],["Jugla",320,"2",47,"Vidzemes al. 2, Riga, Latvia"],["centrs",250,"1",31,"Bru\u0146inieku 93A, Riga, Latvia"],["Maskavas priek\u0161pils\u0113ta",300,"1",35,"Jersikas 37, Riga, Latvia"],["\u0136engarags",350,"3",65,"Bultu 3, Riga, Latvia"],["centrs",500,"2",40,"Laboratorijas 25, Riga, Latvia"],["centrs",330,"2",31,"Klij\u0101nu 12, Riga, Latvia"],["Me\u017eaparks",1700,"5",118,"Hamburgas 8, Riga, Latvia"],["\u0136engarags",290,"1",39,"Lokomot\u012bves 80, Riga, Latvia"],["Me\u017eciems",400,"2",49,"Eizen\u0161teina 19, Riga, Latvia"],["centrs",215,"1",22,"Avotu 75, Riga, Latvia"],["Maskavas priek\u0161pils\u0113ta",345,"1",20,"Kalna 28, Riga, Latvia"],["\u0136engarags",250,"2",37,"Maskavas 273\u002f3, Riga, Latvia"],["D\u0101rzciems",161,"1",21,"Kaibalas 28, Riga, Latvia"],["Purvciems",320,"1",43,"Purvciema 50, Riga, Latvia"],["\u0160amp\u0113teris-Pleskod\u0101le",200,"1",30,"Kalnciema 116c, Riga, Latvia"],["Jugla",360,"1",35,"Tirzas 3, Riga, Latvia"],["Maskavas priek\u0161pils\u0113ta",360,"2",46,"Kato\u013cu 31, Riga, Latvia"],["Vecm\u012blgr\u0101vis",200,"1",20,"Emmas 28, Riga, Latvia"],["\u0160amp\u0113teris-Pleskod\u0101le",900,"3",93,"Lielirbes 13, Riga, Latvia"],["\u0100genskalns",700,"2",67,"Lielirbes 13, Riga, Latvia"],["\u0100genskalns",1700,"3",184,"Lielirbes 13, Riga, Latvia"],["centrs",850,"3",60,"\u010caka 123, Riga, Latvia"],["\u0160amp\u0113teris-Pleskod\u0101le",590,"3",92,"Lielirbes 13, Riga, Latvia"],["centrs",2400,"5",150,"\u0122ertr\u016bdes 19\u002f21, Riga, Latvia"],["Teika",425,"2",34,"Burtnieku 1, Riga, Latvia"],["P\u013cavnieki",460,"2",47,"Salnas 21, Riga, Latvia"],["centrs",1300,"3",104,"Vesetas 15, Riga, Latvia"],["\u0100genskalns",1500,"5",155,"Balo\u017eu 33, Riga, Latvia"],["Imanta",300,"2",50,"Dammes 30, Riga, Latvia"],["P\u013cavnieki",360,"1",38,"Kaudz\u012b\u0161u 1, Riga, Latvia"],["centrs",385,"1",46,"Tomsona 13, Riga, Latvia"],["centrs",2200,"4",142,"Jeruzalemes 10, Riga, Latvia"],["Teika",810,"1",12,"Zemgala 77, Riga, Latvia"],["\u0136engarags",270,"1",35,"Salaspils 8, Riga, Latvia"],["centrs",800,"2",60,"Birznieka-Up\u012b\u0161a 13, Riga, Latvia"],["Sarkandaugava",165,"1",24,"Zieme\u013cu 17, Riga, Latvia"],["centrs",450,"3",70,"Br\u012bv\u012bbas 152, Riga, Latvia"],["D\u0101rzciems",200,"1",25,"Pildas 44a, Riga, Latvia"],["Gr\u012bzi\u0146kalns",230,"2",40,"P\u0113rnavas 55, Riga, Latvia"],["Vecr\u012bga",650,"2",55,"Va\u013c\u0146u 19, Riga, Latvia"],["Purvciems",270,"1",28,"Zvaigzn\u0101ja g. 3, Riga, Latvia"],["centrs",700,"2",60,"Va\u013c\u0146u ...

# %% [markdown]
# # Save data to .pkl format to keep column data types intact as opposed to csv/xlsx file types.

# %%
df_data.to_pickle('riga_listings_data.pkl')
# Out:
# Size
# 50     64
# 30     55
# 40     39
# 42     36
# 25     36
#        ..
# 224     1
# 105     1
# 117     1
# 144     1
# 263     1
# Name: count, Length: 153, dtype: int64
